# %%
#pip install pyyaml
# Out:
# Collecting pyyaml
#   Downloading PyYAML-5.3.1.tar.gz (269 kB)
#      |████████████████████████████████| 269 kB 595 kB/s eta 0:00:01
# Building wheels for collected packages: pyyaml
#   Building wheel for pyyaml (setup.py) ... done
#   Created wheel for pyyaml: filename=PyYAML-5.3.1-cp36-cp36m-linux_x86_64.whl size=44621 sha256=b99d39f5fd6ea865ecf53448f3ae769854fbb943dd36e1fd1f5ab1e1fa5137c7
#   Stored in directory: /home/shishir/.cache/pip/wheels/e5/9d/ad/2ee53cf262cba1ffd8afe1487eef788ea3f260b7e6232a80fc
# Successfully built pyyaml
# Installing collected packages: pyyaml
# Successfully installed pyyaml-5.3.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import easyocr

# %%
#download the model
reader = easyocr.Reader(['en'], gpu = False)
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete

# %%
# show an image
import PIL
from PIL import ImageDraw
#im = PIL.Image.open("invoice1.png")
im = PIL.Image.open("france.jfif")
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225 at 0x7F32E1262588>

# %%
# Doing OCR. Get bounding boxes.
bounds = reader.readtext('france.jfif')
bounds
# Out:
# [([[35, 45], [195, 45], [195, 81], [35, 81]],
#   'Welcome to',
#   0.9703634977340698),
#  ([[34, 74], [192, 74], [192, 124], [34, 124]], 'France', 0.983652651309967)]

# %%
# Draw bounding boxes
def draw_boxes(image, bounds, color='red', width=2):
    draw = ImageDraw.Draw(image)
    for bound in bounds:
        p0, p1, p2, p3 = bound[0]
        draw.line([*p0, *p1, *p2, *p3, *p0], fill=color, width=width)
    return image

draw_boxes(im, bounds)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225 at 0x7F32E1262588>

# %%
len(bounds)
# Out:
# 2

# %%
for i in bounds:
    print(i[1])
# Out:
# Welcome to
# France
